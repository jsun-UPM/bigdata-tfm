# %%
#from anaconda terminal: pip install https://s3-us-west-2.amazonaws.com/ai2-s2-scispacy/releases/v0.5.4/en_core_sci_sm-0.5.4.tar.gz

# %%
import spacy
import re
from scispacy.abbreviation import AbbreviationDetector
import pandas as pd
import json
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Data Extraction

# %%
data = ""
with open('data/DoaScoring.json', encoding='utf-8-sig') as fh:
    data = json.load(fh)
data_df = pd.DataFrame(data)

X, X_test = train_test_split(data_df, test_size=0.1, random_state=42)
X_train, X_val = train_test_split(X, test_size=0.2, random_state=42)
print("test",X_test.shape)
print("train",X_train.shape)
print("val",X_val.shape)
# Out:
# test (39, 49)
# train (276, 49)
# val (70, 49)

# %% [markdown]
# # Functions

# %% [markdown]
# Given a list, it will remove the duplicates from it.

# %%
def unique(item_list):
    unique_list = []
    for item in item_list:
        if item.strip() not in unique_list:
            unique_list.append(item)
    return unique_list

# %% [markdown]
# Applies a regular expression to the input text to match those words that can potentially be acronyms

# %%
def acronym_pattern(text):
    acronym_pattern = r'\b(?=(?:[a-z\d-]*[A-Z]){2})[A-Za-z\d]+(?:-[A-Za-z\d]+)*\b'
    matches = re.findall(acronym_pattern, text)
    return matches

# %% [markdown]
# Uses custom logic to identify if a string is an acronym. If it is an acronym, it gets stored in a list and returned

# %%
def acronym_catcher (acronynm_unique_list):
    upper_case_pattern = r'[A-Z]'
    remove_plural_pattern = r's$'
    filtered_acronym_unique_list = []
    for word in acronynm_unique_list:
        compounds_list = word.split("-")
        word_len = len(word)
        compounds_num = len(compounds_list)
        upper_case = re.findall(upper_case_pattern,word)
        upper_case_num = (len(upper_case))
        if(upper_case):
            if(((word_len-(compounds_num-1))/upper_case_num) <3):
                acronym = word
                if(re.search(remove_plural_pattern,word)):
                    acronym=word.strip()[:-1]
                filtered_acronym_unique_list.append(acronym)
    return filtered_acronym_unique_list

# %% [markdown]
# Finds acronyms in the input text that have an expanded form in it and stores it in a list.

# %%
def acronym_expansion_detector(text):
    nlp = spacy.load( 'en_core_sci_sm')
    nlp.add_pipe("abbreviation_detector")
    doc = nlp( text )
    abrvs = []
    for abrv in doc._.abbreviations:
        abrvs.append(str(abrv))
    return abrvs

# %% [markdown]
# Remove those acronyms that don't get categorized by Spacy NER because most common acronyms don't get recognized. It is a way to remove common acronyms dynamically.

# %%
def spacy_ner(text):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    ner_string = ""
    for ent in doc.ents:
        ner_string +=f" {ent.text}"
        #print(ent.label_)
    return ner_string

# %% [markdown]
# Import all currency acronyms list and use it to weed out currency acronyms as they count as common acronyms. https://www.dst.dk/en/Statistik/dokumentation/nomenklaturer/valuta-iso

# %%
def currency_excluder (acronyms):
    currency_list = pd.read_csv("data/iso-currency.csv",sep=";")
    acronyms_final_list = []
    chars_pattern = r'[A-Z]*'
    for acronym in acronyms:
        #acr_list = re.findall(chars_pattern,acronym.upper())
        if acronym not in list(currency_list["CODE"]):
            acronyms_final_list.append(acronym)
    return acronyms_final_list

# %%
def acronym_detector(id,text):
    print(id)
    matches = acronym_pattern(text)
    acronynm_unique_list = unique(matches)
    filtered_acronym_unique_list = acronym_catcher(acronynm_unique_list)
    filtered_acronym_unique_list = unique(filtered_acronym_unique_list)
    
    print("acronyms found")
    print(filtered_acronym_unique_list)
    listToStr = ' '.join(map(str, acronynm_unique_list))
    
    abrvs = acronym_expansion_detector(text)
    unique_expanded_acr = unique(abrvs)
    ner_string = spacy_ner(text)
    remove_common_acronym_list = filtered_acronym_unique_list.copy()
    for acronym in filtered_acronym_unique_list:
        if(acronym not in ner_string):
            remove_common_acronym_list.remove(acronym)
    #final_acronym_list = currency_excluder(remove_common_acronym_list)
    final_acronym_list=remove_common_acronym_list
    print("acronyms parsed")
    print(final_acronym_list)
    print("acronyms with expanded form")
    print(unique_expanded_acr)
    print("---")
    return {"opportunity_id":id,"acronyms":final_acronym_list,"expanded_acronyms":unique_expanded_acr}

# %%
acronyms_processed = []
data = ""
with open('data/DoaScoring-AcronymDetectionData.json', encoding='utf-8-sig') as fh:
    data = json.load(fh)
data_df = pd.DataFrame(data)
for index, doa in data_df.iterrows():
    acronyms_processed.append(acronym_detector(doa["opportunity_id"],f'''{doa["task_description"]} {doa["organization_mission"]} {doa["context"]} {doa["living_conditions"]} {doa["required_skill_experience"]}'''))
# Out:
# 1720911047380224
# acronyms found
# ['UN', 'AoR', 'UNICEF', 'CP', 'HRP', 'PIN', 'IMO', 'GBV', 'IM', 'CPIMS', 'AOR', 'KM', 'IDP', 'COVID-19', 'NGO']
# C:\Users\sonia\Documents\anaconda3\envs\python3_8_5\lib\site-packages\spacy\language.py:2195: FutureWarning: Possible set union at position 6328
#   deserializers["tokenizer"] = lambda p: self.tokenizer.from_disk(  # type: ignore[union-attr]
# acronyms parsed
# ['UN', 'AoR', 'UNICEF', 'CP', 'HRP', 'PIN', 'GBV', 'IM', 'CPIMS', 'AOR', 'KM', 'COVID-19', 'NGO']
# acronyms with expanded form
# ['IDP']
# ---
# 1724754261095680
# acronyms found
# ['UNV', 'UN', 'UNICEF', 'HQ', 'MOLISA', 'HIV', 'SDG', 'NGO']
# C:\Users\sonia\Documents\anaconda3\envs\python3_8_5\lib\site-packages\scispacy\abbreviation.py:248: UserWarning: [W036] The component 'matcher' does not have any patterns defined.
#   global_matches = self.global_matcher(doc)
# acronyms parsed
# ['UNV', 'UN', 'UNICEF', 'HQ']
# acronyms with expanded form
# []
# ---
# 1715975314313472
# acronyms found
# ['UN', 'IPRCC', 'UNDP', 'UNV', 'IVD', 'COVID-19', 'SDG', 'SDG1', 'SDG5', 'VLA', '490RMB', 'NUNV']
# acronyms parsed
# ['UN', 'IPRCC', 'UNDP', 'UNV', 'IVD', 'COVID-19', 'SDG', 'SDG1', 'SDG5', '490RMB', 'NUNV']
# acronyms with expanded form
# ['UNDP', 'IPRCC', 'SDGs', 'VLA']
# ---
# 1715556939709696
# acronyms found
# ['UN', 'ECM', 'CP', 'UNV', 'IVD', 'UNICEF', 'ICO', 'AGD', 'POCSO', 'CSO', 'VLA', 'INR', 'USD']
# acronyms parsed
# ['UN', 'ECM', 'UNV', 'IVD', 'UNICEF', 'ICO', 'INR', 'USD']
# acronyms with expanded form
# ['AGD', 'POCSO', 'VLA']
# ---
# 1742156550684928
# acronyms found
# ['UNV', 'UNICEF', 'UNICEF-owned', 'ROSA', 'UN', 'AGD', 'HIV', 'AIDS', 'IT']
# acronyms parsed
# ['UNV', 'UNICEF', 'ROSA', 'UN']
# acronyms with expanded form
# ['AGD', 'ROSA']
# ---
# 1726265068252416
# acronyms found
# ['KEY', 'END-RESULTS', 'EXPECTED', 'ADB', 'SP', 'WB', 'UN', 'UNV', 'UNICEF', 'COVID-19', 'ARTF', 'USD']
# acronyms parsed
# ['WB', 'UN', 'UNV', 'UNICEF', 'COVID-19']
# acronyms with expanded form
# ['ADB', 'M&E', 'WB', 'ARTF']
# ---
# 1723329392544000
# acronyms found
# ['UNV', 'UNICEF', 'C-MPI', 'CSO', 'UN', 'PSFR', 'UNSDCF', 'MYR', 'USD', 'MS']
# acronyms parsed
# ['UNV', 'UNICEF', 'UN', 'UNSDCF', 'MYR', 'USD', 'MS']
# acronyms with expanded form
# ['C-MPI', 'PSFR', 'UNSDCF']
# ---
# 1747133756488960
# acronyms found
# ['UNICEF', 'WASH-CCES', 'WASH', 'UN', 'SBCC', 'GHD', 'WTD', 'NFHS', 'NSSO', 'NAARS', 'ECM', 'AWC', 'HCF', 'MHM', 'UNV', 'ICO', 'AGD', 'IEC', 'JJM', 'BASUDHA', 'SBM', 'GoI', 'ODF', 'II', 'FSM', 'IHHL', 'HH', 'FHTC', 'GOI', 'SBSV', 'COVID-19', 'CCES', 'OCCAP', 'BCE', 'CE', 'VLA', 'INR', 'USD']
# acronyms parsed
# ['UNICEF', 'WASH', 'UN', 'SBCC', 'WTD', 'NFHS', 'NSSO', 'NAARS', 'ECM', 'UNV', 'ICO', 'SBM', 'GoI', 'ODF', 'II', 'FSM', 'GOI', 'SBSV', 'COVID-19', 'BCE', 'CE', 'VLA', 'USD']
# acronyms with expanded form
# ['AGD', 'IEC', 'JJM', 'SBM', 'GoI', 'FSM', 'SBSV', 'CCES', 'OCCAP', 'VLA']
# ---
# 1736163346586880
# acronyms found
# ['UNV', 'PPT', 'UN', 'UNICEF', 'CRC', 'CAP', 'ECD', 'ADE', 'MNC', 'VLA', 'INR', 'USD', 'SARS-CoV-2', 'WHO', 'MS']
# acronyms parsed
# ['UNV', 'PPT', 'UN', 'UNICEF', 'CRC', 'CAP', 'ADE', 'VLA', 'INR', 'USD', 'WHO', 'MS']
# acronyms with expanded form
# ['UNICEF', 'CAP', 'ECD', 'ADE']
# ---
# 1726499912258816
# acronyms found
# ['UNV', 'UNICEF', 'HR', 'ROSA', 'GSSC', 'UN', 'AGD', 'HIV', 'AIDS', 'MS']
# acronyms parsed
# ['UNV', 'UNICEF', 'HR', 'ROSA', 'GSSC', 'UN', 'MS']
# acronyms with expanded form
# ['AGD']
# ---
# 1729604249646336
# acronyms found
# ['UNV', 'UNICEF', 'WG', 'SDG', 'HIV', 'AIDS', 'STI', 'UN', 'MS']
# acronyms parsed
# ['UNV', 'UNICEF', 'WG', 'UN', 'MS']
# acronyms with expanded form
# ['STIs']
# ---
# 1718458028817664
# acronyms found
# ['UNDP', 'YELL', 'UNICEF', 'UNSDCF', 'SDG', 'ALAM', 'ERL', 'KL', 'ATM', 'MS']
# acronyms parsed
# ['UNDP', 'YELL', 'UNICEF', 'UNSDCF', 'ALAM', 'ERL', 'KL']
# acronyms with expanded form
# ['YELL', 'UNDP', 'UNICEF', 'ALAM', 'ERL']
# ---
# 1730658147002624
# acronyms found
# ['GenU', 'II', 'III', 'UN', 'UNV', 'UNICEF', 'CSO', 'AGD', 'NGO', 'MNC', 'VLA', 'INR', 'USD', 'SARS-CoV-2', 'WHO', 'MS']
# acronyms parsed
# ['GenU', 'II', 'UN', 'UNV', 'UNICEF', 'VLA', 'INR', 'USD', 'MS']
# acronyms with expanded form
# ['AGD', 'GenU']
# ---
# 1726446134748416
# acronyms found
# ['UNICEF', 'UNV', 'CCEOP', 'EVM', 'PHLMC', 'PHD', 'GAVI', 'SOP', 'FWD', 'MD', 'TSU', 'RI', 'UN', 'AGD', 'HIV', 'AIDS', 'NIP', 'EPI', 'MS', 'e-LMIS']
# acronyms parsed
# ['UNICEF', 'UNV', 'CCEOP', 'PHD', 'FWD', 'TSU', 'UN', 'NIP', 'EPI', 'MS']
# acronyms with expanded form
# ['AGD', 'NIP', 'PHLMC', 'CCEOP', 'EVM', 'chain']
# ---
# 1719583608958208
# acronyms found
# ['UN', 'NOB', 'UNICEF', 'NY', 'HQ', 'UNV', 'IVD', 'AIDS', 'CO', 'VLA', 'RMB', 'MS']
# acronyms parsed
# ['UN', 'UNICEF', 'HQ', 'UNV', 'IVD', 'CO', 'RMB', 'MS']
# acronyms with expanded form
# ['VLA']
# ---
# 1751902024519936
# acronyms found
# ['AIS', 'UN', 'UNDP', 'SDG', 'UNV']
# acronyms parsed
# ['AIS', 'UN', 'UNDP', 'SDG']
# acronyms with expanded form
# ['AIS']
# ---
# 1744107827224832
# acronyms found
# ['SESP', 'UNV', 'MoEST', 'DACS', 'UN', 'UNICEF', 'MoU', 'AGD', 'HIV', 'AIDS', 'SWAp', 'LEDPG', 'JFP', 'CSO', 'JFA', 'TA', 'ToR', 'TWG', 'MOEST']
# acronyms parsed
# ['SESP', 'UNV', 'MoEST', 'DACS', 'UN', 'UNICEF', 'MoU', 'LEDPG', 'JFP', 'TA', 'ToR']
# acronyms with expanded form
# ['AGD', 'SWAp', 'DACS', 'LEDPG', 'CSOs', 'SESP']
# ---
# 1739676612489472
# acronyms found
# ['UN', 'SIKAI', 'DRRM', 'IOM', 'UNV', 'DRR', 'AGD', 'MiGOF', 'SDG', 'UNSDCF', 'GCM', 'ICSC', 'WBD', 'MS']
# acronyms parsed
# ['UN', 'SIKAI', 'IOM', 'UNV', 'DRR', 'MiGOF', 'UNSDCF', 'ICSC', 'MS']
# acronyms with expanded form
# ['AGD', 'MiGOF', 'SDGs', 'UNSDCF', 'GCM', 'WBD']
# ---
# 1744638094383360
# acronyms found
# ['UNV', 'CO', 'GCCF', 'CFN', 'UNDP', 'GCF', 'GEF', 'UN', 'GCCF-III', 'TOR', 'ToR', 'MOF', 'MoFE', 'CCMD', 'PA', 'VISION', 'STATEMENT', 'RBAP', 'BRH', 'UNCDF', 'ICIMOD', 'UN-Women', 'FCDO', 'CARA', 'LoCAL', 'EU', 'NDC', 'NAP', 'MRV', 'MS']
# acronyms parsed
# ['UNV', 'CO', 'CFN', 'UNDP', 'GCF', 'GEF', 'UN', 'MOF', 'MoFE', 'PA', 'RBAP', 'BRH', 'UNCDF', 'UN-Women', 'FCDO', 'CARA', 'LoCAL', 'EU', 'NAP', 'MRV', 'MS']
# acronyms with expanded form
# ['CO', 'MoFE', 'RBAP', 'BRH', 'GCCF', 'CARA', 'CFN']
# ---
# 1728361581305088
# acronyms found
# ['UNDP', 'PVTG', 'PMU', 'CCD', 'UN', 'SDG', 'ST', 'IT', 'XVIII', 'VLA', 'INR', 'UNV']
# acronyms parsed
# ['UNDP', 'PVTG', 'PMU', 'CCD', 'UN', 'INR', 'UNV']
# acronyms with expanded form
# ['SDGs', 'STs', 'VLA']
# ---
# 1723483137819904
# acronyms found
# ['UN', 'UNDP', 'SDG', 'AIDS', 'SAMOA', 'SIDS', 'MCO', 'UNSDG', 'FSM', 'RMI']
# acronyms parsed
# ['UN', 'UNDP', 'SDG', 'AIDS', 'MCO', 'UNSDG', 'FSM', 'RMI']
# acronyms with expanded form
# ['SIDS', 'FSM', 'RMI']
# ---
# 1730826777486592
# acronyms found
# ['UN', 'NGO', 'GP', 'DRR', 'GIS', 'UNDP', 'NDMA', 'PDNA', 'XVIII', 'VLA', 'INR', 'UNV', 'IT']
# acronyms parsed
# ['UN', 'GP', 'DRR', 'GIS', 'UNDP', 'NDMA', 'INR', 'UNV']
# acronyms with expanded form
# ['NDMA', 'PDNA', 'VLA']
# ---
# 1718087658102016
# acronyms found
# ['WHO', 'C4H', 'UNV', 'MOH', 'WTO', 'UN', 'ASEAN', 'MS']
# acronyms parsed
# ['WHO', 'UNV', 'MOH', 'WTO', 'UN', 'ASEAN', 'MS']
# acronyms with expanded form
# ['WHO', 'MOH']
# ---
# 1719869099853056
# acronyms found
# ['LMC', 'UN', 'UNV', 'NAST', 'UNDP', 'VISION', 'STATEMENT', 'SDG', 'FGC', 'MOU', 'TOR', 'CMS']
# acronyms parsed
# ['UN', 'UNV', 'NAST', 'UNDP', 'FGC', 'MOU', 'TOR', 'CMS']
# acronyms with expanded form
# ['LMC', 'SDGs', 'NAST', 'UNDP', 'FGC']
# ---
# 1730380119308544
# acronyms found
# ['SDG', 'CSO', 'UN', 'UNDP', 'UNV', 'AGD', 'USD', 'MS']
# acronyms parsed
# ['SDG', 'UN', 'UNDP', 'UNV', 'USD', 'MS']
# acronyms with expanded form
# ['AGD', 'SDGs']
# ---
# 1718548951612672
# acronyms found
# ['UNAMA', 'UN', 'DPKO', 'ICSC', 'WBD', 'IT']
# acronyms parsed
# ['UNAMA', 'UN', 'DPKO', 'ICSC']
# acronyms with expanded form
# ['DPKO', 'WBD']
# ---
# 1729086393942272
# acronyms found
# ['UN', 'UNAMA', 'ERP', 'SAP', 'DPKO', 'NATO', 'UNOCA', 'SRSG', 'USD', 'DVD', 'VCD']
# acronyms parsed
# ['UN', 'UNAMA', 'ERP', 'SAP', 'NATO', 'UNOCA', 'USD']
# acronyms with expanded form
# ['DPKO', 'UNOCA']
# ---
# 1749620970666240
# acronyms found
# ['MNCH', 'UN', 'UNV', 'UNICEF', 'WHO', 'IMNCI', 'ECEB', 'ECSB', 'HBB', 'CCM', 'CBNBC', 'MHPSS', 'IPC', 'PHC', 'ODK', 'BI', 'CDM']
# acronyms parsed
# ['MNCH', 'UN', 'UNV', 'UNICEF', 'WHO', 'IMNCI', 'ECSB', 'CCM', 'IPC', 'PHC', 'ODK']
# acronyms with expanded form
# ['ECEB', 'ECSB', 'CBNBC', 'IPC', 'UNICEF', 'CDM']
# ---
# 1748972773842176
# acronyms found
# ['UN', 'HR', 'UNDP', 'COVID-19', 'GoSL', 'SDG16', 'UNICEF']
# acronyms parsed
# ['UN', 'UNDP', 'COVID-19', 'GoSL', 'SDG16']
# acronyms with expanded form
# ['UNDP', 'GoSL', 'UNICEF', 'Programme']
# ---
# 1737023049212160
# acronyms found
# ['TEPP', 'IP', 'UNDP', 'MDG', 'SDG', 'NHRC', 'PMO', 'BBS', 'NLASO', 'NGO', 'IMED', 'ICT', 'BIDA', 'DBID', 'G2B', 'MP', 'GIU', 'LDC', 'NGOAB', 'UN']
# acronyms parsed
# ['IP', 'UNDP', 'NHRC', 'NGO', 'IMED', 'ICT', 'BIDA', 'GIU', 'NGOAB', 'UN']
# acronyms with expanded form
# ['UNDP', 'MDGs', 'SDGs', 'IP', 'NHRC', 'PMO', 'BBS', 'NLASO', 'IMED', 'ICT', 'BIDA', 'DBID', 'GIU']
# ---
# 1722555707414784
# acronyms found
# ['NUNV', 'UPSHIFT', 'UN', 'CSO', 'II', 'SOP', 'UNICEF', 'III', 'SDG', 'GenU', 'MNC', 'VLA', 'INR', 'USD', 'UNV']
# acronyms parsed
# ['NUNV', 'UPSHIFT', 'UN', 'II', 'UNICEF', 'GenU', 'INR', 'USD', 'UNV']
# acronyms with expanded form
# ['GenU']
# ---
# 1712606683150592
# acronyms found
# ['UNV', 'PCA', 'RWP', 'HPM', 'UNICEF', 'CR', 'PM', 'HACT', 'UN', 'USD', 'MS', 'ARC', 'GIS']
# acronyms parsed
# ['UNV', 'HPM', 'UNICEF', 'CR', 'PM', 'UN', 'MS', 'ARC']
# acronyms with expanded form
# ['PCAs']
# ---
# 1737192573379840
# acronyms found
# ['LoCAL', 'UNCDF', 'IT', 'UN', 'UNV', 'AGD', 'LGA', 'LDC', 'SDG', 'SDG1', 'SDG13', 'CCA', 'PBCRG', 'PBCRGS', 'IUNV', 'UNDSS', 'LOW', 'UNDP']
# acronyms parsed
# ['LoCAL', 'UNCDF', 'UN', 'UNV', 'CCA', 'PBCRG', 'IUNV', 'UNDP']
# acronyms with expanded form
# ['AGD', 'LoCAL', 'LGAs', 'SDGs', 'PBCRGs']
# ---
# 1717220336857344
# acronyms found
# ['UNV', 'CO', 'UNICEF', 'UN', 'USD', 'MS']
# acronyms parsed
# ['UNV', 'CO', 'UNICEF', 'UN', 'MS']
# acronyms with expanded form
# []
# ---
# 1738258918508800
# acronyms found
# ['UN', 'IUDP', 'GESI', 'DRR', 'UNOPS', 'UNV', 'SDG', 'GIS']
# acronyms parsed
# ['UN', 'IUDP', 'GESI', 'UNOPS', 'UNV', 'GIS']
# acronyms with expanded form
# ['IUDP']
# ---
# 1748685903188224
# acronyms found
# ['UNV', 'WEF', 'BAPPENAS', 'UN', 'SDG', 'NGO', 'UNDP', 'FAO']
# acronyms parsed
# ['UNV', 'BAPPENAS', 'UN', 'SDG', 'UNDP', 'FAO']
# acronyms with expanded form
# []
# ---
# 1735863691344128
# acronyms found
# ['UNDP', 'SDG', 'PMO', 'UNV', 'NIM', 'CICETE', 'NGO', 'UN', 'UNIDO', 'VLA', 'RMB']
# acronyms parsed
# ['UNDP', 'SDG', 'PMO', 'UNV', 'NIM', 'CICETE', 'UN', 'UNIDO', 'RMB']
# acronyms with expanded form
# ['PMO', 'UNDP', 'NGOs', 'VLA']
# ---
# 1729850533315840
# acronyms found
# ['UN', 'WEE', 'PPT', 'EU', 'UNGTG', 'ACWF', 'RO', 'RCO', 'UNDP', 'UNV', 'AGD', 'SN', 'VLA', 'RMB', 'CV']
# acronyms parsed
# ['UN', 'WEE', 'PPT', 'EU', 'UNGTG', 'ACWF', 'RO', 'RCO', 'UNDP', 'UNV', 'SN', 'CV']
# acronyms with expanded form
# ['AGD', 'SN', 'VLA']
# ---
# 1724294909239552
# acronyms found
# ['RAM', 'UN', 'WFP', 'CO', 'AO', 'UNV', 'AGD', 'SDG', 'IV', 'MORSS', 'UNDSS', 'MS', 'SPSS', 'PowerBI']
# acronyms parsed
# ['RAM', 'UN', 'WFP', 'CO', 'AO', 'UNV', 'SDG', 'IV', 'MS', 'SPSS']
# acronyms with expanded form
# ['RAM', 'AO', 'AGD', 'SDG']
# ---
# 1727287204035840
# acronyms found
# ['UNV', 'UNICEF', 'CHN-Supply', 'LVPO', 'UN', 'AGD', 'VLA', 'RMB', 'MS', 'PSEA']
# acronyms parsed
# ['UNV', 'UNICEF', 'CHN-Supply', 'UN', 'RMB', 'MS', 'PSEA']
# acronyms with expanded form
# ['LVPO', 'AGD', 'VLA']
# ---
# 1719066042423552
# acronyms found
# ['SESEHA', 'UN', 'PV', 'UNV', 'UNDP', 'SDG', 'ABADEI', 'UN-led', 'KfW', 'USD', 'AutoCAD', 'PVSol', 'MS', 'KFW', 'NGO', 'CSO']
# acronyms parsed
# ['SESEHA', 'UN', 'PV', 'UNV', 'UNDP', 'ABADEI', 'KfW', 'PVSol', 'MS', 'KFW']
# acronyms with expanded form
# ['SESEHA', 'SDGs', 'ABADEI', 'renewable energy']
# ---
# 1734838521537792
# acronyms found
# ['UN', 'UNODC', 'UNEP', 'UNV', 'IP', 'AGD', 'ROAP', 'MEA', 'MS']
# acronyms parsed
# ['UN', 'UNODC', 'UNEP', 'UNV', 'IP', 'MEA', 'MS']
# acronyms with expanded form
# ['UNODC', 'non-', 'IPs', 'AGD', 'UNEP', 'UNEP/ROAP', 'MEAs']
# ---
# 1740390291898624
# acronyms found
# ['UNV', 'UNICEF', 'UN', 'AGD', 'IT', 'UNSMS', 'DSA', 'MS']
# acronyms parsed
# ['UNV', 'UNICEF', 'UN', 'UNSMS', 'MS']
# acronyms with expanded form
# ['AGD', 'UNSMS']
# ---
# 1735158341286144
# acronyms found
# ['UNV', 'UN', 'UNDP', 'MCO', 'ID', 'DSA', 'SOP', 'SDG', 'MCPD', 'UNSDCF', 'PIC', 'ATM', 'MS']
# acronyms parsed
# ['UNV', 'UN', 'UNDP', 'MCO', 'MCPD', 'UNSDCF', 'MS']
# acronyms with expanded form
# ['SDGs', 'UNDP', 'MCO', 'PICs', 'iii']
# ---
# 1720381855226112
# acronyms found
# ['UNDP', 'UN', 'GESI', 'CSO', 'MEAL', 'UNV', 'QA', 'PIANGO', 'AGD', 'SDG', 'PIC', 'PFM', 'MS']
# acronyms parsed
# ['UNDP', 'UN', 'GESI', 'CSO', 'UNV', 'QA', 'SDG', 'PIC', 'PFM', 'MS']
# acronyms with expanded form
# ['AGD', 'PICs', 'project']
# ---
# 1714648120889600
# acronyms found
# ['AHF', 'OCHA', 'DD', 'ICA', 'TPM', 'RCM', 'CBPF', 'HC', 'HFU', 'NGO', 'UN', 'HRP', 'US', 'UNV', 'GMS', 'COVID-19']
# acronyms parsed
# ['AHF', 'OCHA', 'TPM', 'RCM', 'CBPF', 'HC', 'NGO', 'UN', 'HRP', 'US', 'UNV', 'GMS', 'COVID-19']
# acronyms with expanded form
# ['AHF', 'DD/ICA', 'RCM', 'TPM', 'OCHA', 'CBPFs', 'HC', 'HFU', 'HRP', 'CBPF', 'GMS']
# ---
# 1722330536946944
# acronyms found
# ['UNV', 'SCALA', 'MoALD', 'UNDP', 'HQ', 'CO', 'CP', 'FAO', 'UN', 'TWC', 'PSC', 'NDC', 'NAP', 'AGD', 'VISION', 'STATEMENT', 'II', 'BMUB', 'IKI', 'GHG', 'MS']
# acronyms parsed
# ['UNV', 'SCALA', 'UNDP', 'HQ', 'CO', 'CP', 'FAO', 'UN', 'TWC', 'PSC', 'NDC', 'II', 'IKI', 'GHG', 'MS']
# acronyms with expanded form
# ['MoALD', 'AGD', 'NDC']
# ---
# 1728272560700672
# acronyms found
# ['UNDP', 'IT', 'PMU', 'UN', 'SDG', 'ST', 'XVIII', 'VLA', 'INR', 'UNV', 'ICT', 'ASP', 'AJAX']
# acronyms parsed
# ['UNDP', 'PMU', 'UN', 'INR', 'UNV', 'ICT', 'ASP', 'AJAX']
# acronyms with expanded form
# ['PMU', 'SDGs', 'STs', 'VLA']
# ---
# 1749249816247552
# acronyms found
# ['UN', 'UNA', 'RCR', 'SOP', 'UNAMA', 'DPKO', 'MS']
# acronyms parsed
# ['UN', 'UNA', 'RCR', 'UNAMA', 'DPKO', 'MS']
# acronyms with expanded form
# ['DPKO', 'UNAMA']
# ---
# 1722882212262144
# acronyms found
# ['UN', 'IPRCC', 'NGO', 'UNV', 'IVD', 'UNDP', 'COVID-19', 'SDG', 'SDG1', 'SDG5', 'VLA', 'RMB', 'NUNV']
# acronyms parsed
# ['UN', 'IPRCC', 'UNV', 'IVD', 'UNDP', 'COVID-19', 'SDG', 'SDG1', 'SDG5', 'RMB', 'NUNV']
# acronyms with expanded form
# ['UNDP', 'IPRCC', 'SDGs', 'VLA']
# ---
# 1724193944727808
# acronyms found
# ['UNV', 'SBC', 'UN', 'UNICEF', 'USD', 'C4D', 'RCCE', 'MS']
# acronyms parsed
# ['UNV', 'SBC', 'UN', 'UNICEF', 'RCCE', 'MS']
# acronyms with expanded form
# ['SBC', 'RCCE']
# ---
# 1719185397717248
# acronyms found
# ['ACHIEVE', 'UNV', 'UNDP', 'HR', 'UN', 'GoI', 'SDG', 'CO', 'MRT']
# acronyms parsed
# ['ACHIEVE', 'UNV', 'UNDP', 'UN', 'GoI', 'SDG', 'CO', 'MRT']
# acronyms with expanded form
# ['GoI']
# ---
# 1737637619526912
# acronyms found
# ['UN', 'BSST', 'PSST', 'UNV', 'CSO', 'UNICEF', 'NGO']
# acronyms parsed
# ['UN', 'BSST', 'UNV', 'CSO', 'UNICEF']
# acronyms with expanded form
# []
# ---
# 1720842403517696
# acronyms found
# ['UN', 'NIS', 'SMART', 'MUAC', 'T4D', 'IN-FORM', 'ODK', 'OCHA', 'IM', 'WG', 'HRP', 'HNO', 'HPC', 'PIN', 'UNICEF', 'IDP', 'COVID-19', 'ArcGIS', 'QGIS', 'BI']
# acronyms parsed
# ['UN', 'NIS', 'MUAC', 'ODK', 'OCHA', 'IM', 'HNO', 'PIN', 'UNICEF', 'COVID-19', 'ArcGIS', 'QGIS', 'BI']
# acronyms with expanded form
# ['NIS', 'HRP', 'HNO', 'HPC', 'IDP']
# ---
# 1707487970160896
# acronyms found
# ['UN', 'CRVS', 'UNV', 'ESCAP', 'AGD', 'SDG', 'US', 'BTS', 'MRT', 'MS']
# acronyms parsed
# ['UN', 'CRVS', 'UNV', 'ESCAP', 'US', 'BTS', 'MRT', 'MS']
# acronyms with expanded form
# ['AGD', 'ESCAP', 'CRVS']
# ---
# 1736341011691776
# acronyms found
# ['UN', 'UNAMA', 'DPKO', 'UNV', 'UNOCA', 'SRSG', 'USD', 'DVD', 'VCD', 'BOQ']
# acronyms parsed
# ['UN', 'UNAMA', 'DPKO', 'UNOCA', 'USD', 'BOQ']
# acronyms with expanded form
# ['DPKO', 'UNOCA']
# ---
# 1741892835062016
# acronyms found
# ['UN', 'EFMS', 'FMU', 'SAO', 'VIP', 'UNAMA', 'FSS', 'AFP', 'UNAMA-HQ', 'UNOCA', 'RAO', 'HR', 'HQ', 'FTS', 'EFMS-FMU', 'DPKO', 'USD', 'DVD']
# acronyms parsed
# ['UN', 'EFMS', 'SAO', 'UNAMA', 'FSS', 'AFP', 'UNAMA-HQ', 'UNOCA', 'HR', 'HQ', 'FTS', 'DPKO', 'USD']
# acronyms with expanded form
# ['SAO', 'AFP', 'RAO', 'FTS', 'DPKO', 'UNOCA']
# ---
# 1725981123357952
# acronyms found
# ['UN', 'UNICEF', 'UNV', 'WASH', 'MRT', 'ATM', 'MS']
# acronyms parsed
# ['UN', 'UNICEF', 'UNV', 'MRT', 'MS']
# acronyms with expanded form
# ['WASH']
# ---
# 1710941565686016
# acronyms found
# ['UN', 'UNAMA', 'ISW', 'SOW', 'UMOJA', 'MOO', 'SES', 'UNV', 'DPKO', 'UNOCA', 'SRSG', 'USD', 'DVD', 'VCD']
# acronyms parsed
# ['UN', 'UNAMA', 'ISW', 'UMOJA', 'SES', 'UNV', 'DPKO', 'UNOCA', 'USD']
# acronyms with expanded form
# ['Second Reporting Officer', 'ISW', 'MOOs', 'DPKO', 'UNOCA']
# ---
# 1711631973231872
# acronyms found
# ['HCWM', 'SDG', 'HQ', 'UNDP', 'CO', 'MDG', 'LDC', 'LNOB', 'UMIC', '8FYP', 'EPU', 'COVID-19', 'UN', 'INGO']
# acronyms parsed
# ['HCWM', 'SDG', 'UNDP', 'CO', '8FYP', 'EPU', 'UN']
# acronyms with expanded form
# ['UNDP', 'MDGs', 'SDGs', 'LDC', 'LNOB', 'UMIC', 'EPU']
# ---
# 1746577951591680
# acronyms found
# ['UNV', 'UN', 'HR', 'UVP', 'VSC', 'VSS', 'FU', 'ICT', 'UNDP', 'SDG', 'HQ', 'PNG', 'HIV', 'AIDS', 'STD', 'AC', 'IT']
# acronyms parsed
# ['UNV', 'UN', 'UVP', 'VSC', 'VSS', 'FU', 'ICT', 'UNDP', 'PNG', 'AC']
# acronyms with expanded form
# ['SDGs', 'PNG']
# ---
# 1727654131130624
# acronyms found
# ['UN', 'SEADPRI', 'SEADPRI-UKM', 'YELL', 'DRR', 'UNV', 'UNDP', 'UNSDCF', 'SDG', 'UNICEF', 'ALAM', 'LESTARI']
# acronyms parsed
# ['UN', 'SEADPRI', 'SEADPRI-UKM', 'YELL', 'DRR', 'UNDP', 'UNSDCF', 'ALAM', 'LESTARI']
# acronyms with expanded form
# ['SEADPRI', 'DRR', 'UNDP', 'UNICEF', 'ALAM']
# ---
# 1717131082592512
# acronyms found
# ['UN', 'VAT', 'UNDP', 'SOP', 'UNV', 'SDG', 'Framework-ANPDF', 'CO', 'USD', 'HR', 'MS']
# acronyms parsed
# ['UN', 'VAT', 'UNDP', 'UNV', 'Framework-ANPDF', 'CO', 'MS']
# acronyms with expanded form
# ['SOP']
# ---
# 1732533350239488
# acronyms found
# ['UNICEF', 'COVID-10', 'UN', 'NGO', 'RMPU', 'BCO', 'RC', 'PPD', 'COVID-19', 'CPD', 'PMR', 'UNV', 'MS']
# acronyms parsed
# ['UNICEF', 'UN', 'NGO', 'BCO', 'COVID-19', 'CPD', 'PMR', 'UNV', 'MS']
# acronyms with expanded form
# []
# ---
# 1729507457681664
# acronyms found
# ['PMO', 'UN', 'UNV', 'IVD', 'UNDP', 'UNFPA', 'UNOPS', 'BYL', 'BVF', 'CICETE', 'VLA', 'RMB']
# acronyms parsed
# ['PMO', 'UN', 'UNV', 'IVD', 'UNDP', 'BYL', 'BVF', 'VLA', 'RMB']
# acronyms with expanded form
# ['PMO', 'UNDP', 'UNV', 'BYL', 'CICETE', 'VLA']
# ---
# 1728461550524672
# acronyms found
# ['UNICEF', 'UN', 'ECM', 'CP', 'UNV', 'ICO', 'AGD', 'POCSO', 'CSO', 'VLA', 'INR', 'USD', 'SARS-CoV-2', 'WHO']
# acronyms parsed
# ['UNICEF', 'UN', 'ECM', 'UNV', 'ICO', 'INR', 'USD']
# acronyms with expanded form
# ['AGD', 'POCSO', 'VLA']
# ---
# 1726533237289216
# acronyms found
# ['UN', 'SA', 'NOO', 'HCFC', 'HPMP', 'HFC', 'KIP', 'MLF', 'UNEP', 'PCR', 'NOU', 'PCA', 'SSFA', 'UN2UN', 'CAP', 'UNV', 'AGD', 'ODS', 'IT', 'RAC', 'GWP', 'UNDP', 'UNIDO', 'GIZ', 'US', 'BTS', 'MRT', 'MS']
# acronyms parsed
# ['UN', 'SA', 'NOO', 'HCFC', 'HPMP', 'HFC', 'KIP', 'MLF', 'UNEP', 'CAP', 'UNV', 'ODS', 'RAC', 'UNDP', 'UNIDO', 'GIZ', 'US', 'BTS', 'MRT', 'MS']
# acronyms with expanded form
# ['SA', 'NOOs', 'HPMP', 'KIP', 'MLF', 'PCR', 'AGD', 'ODS', 'HFC', 'CAP', 'HCFC', 'RAC', 'NOUs']
# ---
# 1745158053526784
# acronyms found
# ['PMR', 'UNICEF', 'UN', 'GIS', 'GPS', 'OM', 'ISCG', 'IMWG', 'INTPA', 'FMM', 'AGD']
# acronyms parsed
# ['PMR', 'UNICEF', 'UN', 'GIS', 'GPS', 'INTPA']
# acronyms with expanded form
# ['IMWG', 'FMM', 'AGD']
# ---
# 1738203900331264
# acronyms found
# ['UN', 'UNDP', 'CO', 'CSO', 'AGD', 'SDG', 'CSDG', 'STA', 'US', 'ATM', 'Wi-Fi', 'MORSS', 'HIV', 'AIDS']
# acronyms parsed
# ['UN', 'UNDP', 'CO', 'CSO', 'STA']
# acronyms with expanded form
# ['AGD', 'SDGs', 'oversight', 'CSDGs', 'Kampong Cham', 'Siem Reap']
# ---
# 1717366139706624
# acronyms found
# ['FAO', 'UN', 'MEAL', 'UNV', 'UNSDCF', 'IPC', 'CPF', 'USD', 'MORSS', 'COVID-19', 'HIV', 'AIDS']
# acronyms parsed
# ['FAO', 'UN', 'UNV', 'UNSDCF', 'IPC', 'COVID-19']
# acronyms with expanded form
# ['CPF']
# ---

# %% [markdown]
# ## Check the result against the validation data

# %% [markdown]
# Import the file

# %%
val_data = ""
with open('data/DoaScoring-AcronymDetectionLabels.json', encoding='utf-8-sig') as fh:
    val_data = json.load(fh)

# %% [markdown]
# extract the data needed for the validation

# %%
val_acronyms = []
chatgpt_acronyms = []
for doa in val_data:
    final_acronyms_list = doa["acronyms"].copy()
    chatgpt_acronyms = list(doa["chatgpt"].keys())
    for ignore in doa["ignoreList"]:
        if ignore in doa["acronyms"]:
            final_acronyms_list.remove(ignore)
    val_acronyms.append({"opportunity_id": doa["opportunity_id"],"acronyms":final_acronyms_list,"chatgpt":chatgpt_acronyms,"expanded_form":doa["expanded form"]})
#print(val_acronyms)

# %% [markdown]
# compare the results from the process with the validation data to get the accuracy and other metrics

# %%
code_acc = 0
chatgpt_acc = 0
code_false_positive = 0
chatgpt_false_positive = 0
total_acronyms = 0
total_expanded_forms = 0 
expanded_form_acc = 0

for doa in val_acronyms:
    total_acronyms += len(doa["acronyms"])
for index,doa in enumerate(val_acronyms):
    print(doa["opportunity_id"])
    total_acronyms_ar_mean = len(doa["acronyms"])
    acronyms_found = 0
    acronyms_found_chatgpt = 0
    acronyms_not_found = 0
    acronyms_not_found_chatgpt = 0
    print("validation acronyms",doa["acronyms"])
    doa_acronym_list = list(map(lambda x: x.upper(),  doa["acronyms"]))
    doa_acronym_expanded_list = list(map(lambda x: list(x.keys())[0],  doa["expanded_form"]))
    total_expanded_forms += len(doa_acronym_expanded_list)
    for doa_processed in acronyms_processed:
        if doa_processed["opportunity_id"] == doa["opportunity_id"]:
            print("processed acronyms",doa_processed["acronyms"])
            for acronym in doa_processed["acronyms"]:
                if acronym.upper() in doa_acronym_list:
                    acronyms_found +=1
                else:
                    acronyms_not_found +=1
            for expanded_acronym in doa_processed["expanded_acronyms"]:
                for expanded_validation in doa_acronym_expanded_list:
                    if expanded_acronym == expanded_validation.upper():
                        expanded_form_acc += 1
    for acronym in val_acronyms[index]["chatgpt"]:
        if acronym.upper() in doa_acronym_list:
            acronyms_found_chatgpt +=1
        else: 
            acronyms_not_found_chatgpt +=1
    code_acc += ((acronyms_found/total_acronyms)*100)
    chatgpt_acc +=((acronyms_found_chatgpt/total_acronyms)*100)
    code_false_positive += ((acronyms_not_found/total_acronyms)*100)
    chatgpt_false_positive +=((acronyms_not_found_chatgpt/total_acronyms)*100)
    
    print(f"code arithmetic mean acc: {(acronyms_found/total_acronyms_ar_mean)*100}%")
    print(f"chatgpt arithmetic mean acc: {(acronyms_found_chatgpt/total_acronyms_ar_mean)*100}%")
    print(f"code arithmetic mean false positive: {(acronyms_not_found/total_acronyms_ar_mean)*100}%")
    print(f"chatgpt arithmetic mean false positive: {(acronyms_not_found_chatgpt/total_acronyms_ar_mean)*100}%")
    print("-----")
print(total_expanded_forms)
print(f"weighted arithmetic code accuracy {code_acc}%")
print(f"weighted arithmetic chatgpt accuracy {chatgpt_acc}%")
print(f"weighted arithmetic code false postives {code_false_positive}%")
print(f"weighted arithmetic chatgpt false positives {chatgpt_false_positive}%")
print(f"wighted arithmetic acronym expanded form detection accuracy {(expanded_form_acc/total_expanded_forms)*100}%")
# Out:
# 1720911047380224
# validation acronyms ['AoR', 'UNICEF', 'CP', 'HRP', 'PIN', 'IMO', 'UNICEF', 'GBV', 'IM', 'CPIMS+', '5Ws', 'IM/KM', 'IDP']
# processed acronyms ['UN', 'AoR', 'UNICEF', 'CP', 'HRP', 'PIN', 'GBV', 'IM', 'CPIMS', 'AOR', 'KM', 'COVID-19', 'NGO']
# code arithmetic mean acc: 61.53846153846154%
# chatgpt arithmetic mean acc: 69.23076923076923%
# code arithmetic mean false positive: 38.46153846153847%
# chatgpt arithmetic mean false positive: 7.6923076923076925%
# -----
# 1724754261095680
# validation acronyms ['UNV', 'UNICEF', 'HQ', 'MOLISA']
# processed acronyms ['UNV', 'UN', 'UNICEF', 'HQ']
# code arithmetic mean acc: 75.0%
# chatgpt arithmetic mean acc: 50.0%
# code arithmetic mean false positive: 25.0%
# chatgpt arithmetic mean false positive: 50.0%
# -----
# 1715975314313472
# validation acronyms ['IPRCC', 'UNDP', 'UNV', 'IVD', 'SDG', '(I)NGO', 'SDG1', 'SDG5', 'VLA']
# processed acronyms ['UN', 'IPRCC', 'UNDP', 'UNV', 'IVD', 'COVID-19', 'SDG', 'SDG1', 'SDG5', '490RMB', 'NUNV']
# code arithmetic mean acc: 77.77777777777779%
# chatgpt arithmetic mean acc: 44.44444444444444%
# code arithmetic mean false positive: 44.44444444444444%
# chatgpt arithmetic mean false positive: 11.11111111111111%
# -----
# 1715556939709696
# validation acronyms ['ECM', 'CP', 'UNV', 'IVD', 'UNICEF', 'ICO', 'POCSO', 'CSO', 'VLA', 'INR']
# processed acronyms ['UN', 'ECM', 'UNV', 'IVD', 'UNICEF', 'ICO', 'INR', 'USD']
# code arithmetic mean acc: 60.0%
# chatgpt arithmetic mean acc: 70.0%
# code arithmetic mean false positive: 20.0%
# chatgpt arithmetic mean false positive: 10.0%
# -----
# 1742156550684928
# validation acronyms ['UNV', 'UNICEF', 'ROSA', 'AGD']
# processed acronyms ['UNV', 'UNICEF', 'ROSA', 'UN']
# code arithmetic mean acc: 75.0%
# chatgpt arithmetic mean acc: 75.0%
# code arithmetic mean false positive: 25.0%
# chatgpt arithmetic mean false positive: 25.0%
# -----
# 1726265068252416
# validation acronyms ['ADB', 'SP', 'M&E', 'WB', 'UNV', 'UNICEF', 'ARTF']
# processed acronyms ['WB', 'UN', 'UNV', 'UNICEF', 'COVID-19']
# code arithmetic mean acc: 42.857142857142854%
# chatgpt arithmetic mean acc: 71.42857142857143%
# code arithmetic mean false positive: 28.57142857142857%
# chatgpt arithmetic mean false positive: 14.285714285714285%
# -----
# 1723329392544000
# validation acronyms ['UNV', 'UNICEF', 'C-MPI', 'CSO', 'PSFR', 'UNSDCF', 'MYR', 'MS']
# processed acronyms ['UNV', 'UNICEF', 'UN', 'UNSDCF', 'MYR', 'USD', 'MS']
# code arithmetic mean acc: 62.5%
# chatgpt arithmetic mean acc: 62.5%
# code arithmetic mean false positive: 25.0%
# chatgpt arithmetic mean false positive: 12.5%
# -----
# 1747133756488960
# validation acronyms ['UNICEF', 'WASH-CCES', 'WASH', 'SBCC', 'GHD', 'WTD', 'NFHS V', 'NSSO', 'NAARS', 'ECM', 'AWC', 'HCF', 'MHM', 'UNV', 'ICO', 'AGD', 'IEC', 'SDG', 'JJM', 'SBM', 'BASUDHA', 'GoI', 'ODF', 'FSM', 'IHHL', 'HH', 'FHTC', 'SBSV', 'CCES', 'OCCAP', 'BCE', 'CE', 'VLA', 'INR']
# processed acronyms ['UNICEF', 'WASH', 'UN', 'SBCC', 'WTD', 'NFHS', 'NSSO', 'NAARS', 'ECM', 'UNV', 'ICO', 'SBM', 'GoI', 'ODF', 'II', 'FSM', 'GOI', 'SBSV', 'COVID-19', 'BCE', 'CE', 'VLA', 'USD']
# code arithmetic mean acc: 52.94117647058824%
# chatgpt arithmetic mean acc: 52.94117647058824%
# code arithmetic mean false positive: 14.705882352941178%
# chatgpt arithmetic mean false positive: 14.705882352941178%
# -----
# 1736163346586880
# validation acronyms ['UNV', 'PPT', 'UNICEF', 'CRC', 'CAP', 'ECD', 'ADE', 'MNC', 'VLA', 'INR', 'WHO', 'MS']
# processed acronyms ['UNV', 'PPT', 'UN', 'UNICEF', 'CRC', 'CAP', 'ADE', 'VLA', 'INR', 'USD', 'WHO', 'MS']
# code arithmetic mean acc: 83.33333333333334%
# chatgpt arithmetic mean acc: 66.66666666666666%
# code arithmetic mean false positive: 16.666666666666664%
# chatgpt arithmetic mean false positive: 25.0%
# -----
# 1726499912258816
# validation acronyms ['UNV', 'UNICEF', 'ROSA', 'GSSC', 'AGD', 'MS']
# processed acronyms ['UNV', 'UNICEF', 'HR', 'ROSA', 'GSSC', 'UN', 'MS']
# code arithmetic mean acc: 83.33333333333334%
# chatgpt arithmetic mean acc: 50.0%
# code arithmetic mean false positive: 33.33333333333333%
# chatgpt arithmetic mean false positive: 0.0%
# -----
# 1729604249646336
# validation acronyms ['UNV', 'UNICEF', 'WG', 'SDG', 'STI', 'MS']
# processed acronyms ['UNV', 'UNICEF', 'WG', 'UN', 'MS']
# code arithmetic mean acc: 66.66666666666666%
# chatgpt arithmetic mean acc: 16.666666666666664%
# code arithmetic mean false positive: 16.666666666666664%
# chatgpt arithmetic mean false positive: 66.66666666666666%
# -----
# 1718458028817664
# validation acronyms ['UNDP', 'YELL', 'UNICEF', 'UNSDCF', 'ALAM', 'ERL', 'KL', 'MS']
# processed acronyms ['UNDP', 'YELL', 'UNICEF', 'UNSDCF', 'ALAM', 'ERL', 'KL']
# code arithmetic mean acc: 87.5%
# chatgpt arithmetic mean acc: 62.5%
# code arithmetic mean false positive: 0.0%
# chatgpt arithmetic mean false positive: 25.0%
# -----
# 1730658147002624
# validation acronyms ['GenU', 'YuWaah', 'UNV', 'UNICEF', 'CSO', 'AGD', 'MNC', 'VLA', 'INR', 'WHO', 'MS']
# processed acronyms ['GenU', 'II', 'UN', 'UNV', 'UNICEF', 'VLA', 'INR', 'USD', 'MS']
# code arithmetic mean acc: 54.54545454545454%
# chatgpt arithmetic mean acc: 54.54545454545454%
# code arithmetic mean false positive: 27.27272727272727%
# chatgpt arithmetic mean false positive: 27.27272727272727%
# -----
# 1726446134748416
# validation acronyms ['UNICEF', 'UNV', 'CCEOP', 'EVM', 'PHLMC', 'GAVI', 'SOP', 'FWD', 'MD', 'TSU', 'RI', 'AGD', 'NIP', 'PHLMC', 'CCEOP', 'EPI', 'e-LMIS', 'MS', 'UN']
# processed acronyms ['UNICEF', 'UNV', 'CCEOP', 'PHD', 'FWD', 'TSU', 'UN', 'NIP', 'EPI', 'MS']
# code arithmetic mean acc: 47.368421052631575%
# chatgpt arithmetic mean acc: 36.84210526315789%
# code arithmetic mean false positive: 5.263157894736842%
# chatgpt arithmetic mean false positive: 0.0%
# -----
# 1719583608958208
# validation acronyms ['NOB', 'NY', 'UNICEF', 'IVD', 'CO', 'VLA', 'RMB']
# processed acronyms ['UN', 'UNICEF', 'HQ', 'UNV', 'IVD', 'CO', 'RMB', 'MS']
# code arithmetic mean acc: 57.14285714285714%
# chatgpt arithmetic mean acc: 57.14285714285714%
# code arithmetic mean false positive: 57.14285714285714%
# chatgpt arithmetic mean false positive: 28.57142857142857%
# -----
# 1751902024519936
# validation acronyms ['AIS', 'UNDP']
# processed acronyms ['AIS', 'UN', 'UNDP', 'SDG']
# code arithmetic mean acc: 100.0%
# chatgpt arithmetic mean acc: 100.0%
# code arithmetic mean false positive: 100.0%
# chatgpt arithmetic mean false positive: 150.0%
# -----
# 1744107827224832
# validation acronyms ['SESP', 'UNV', 'MoEST', 'DACS', 'UNICEF', 'MoU', 'AGD', 'SWAp', 'LEDPG', 'JFP', 'CSO', 'TA', 'ToR', 'TWG']
# processed acronyms ['SESP', 'UNV', 'MoEST', 'DACS', 'UN', 'UNICEF', 'MoU', 'LEDPG', 'JFP', 'TA', 'ToR']
# code arithmetic mean acc: 71.42857142857143%
# chatgpt arithmetic mean acc: 7.142857142857142%
# code arithmetic mean false positive: 7.142857142857142%
# chatgpt arithmetic mean false positive: 28.57142857142857%
# -----
# 1739676612489472
# validation acronyms ['SIKAI', 'DRRM', 'IOM', 'UNV', 'DRR', 'AGD', 'MiGOF', 'UNSDCF', 'GCM', 'ICSC', 'WBD', 'MS']
# processed acronyms ['UN', 'SIKAI', 'IOM', 'UNV', 'DRR', 'MiGOF', 'UNSDCF', 'ICSC', 'MS']
# code arithmetic mean acc: 66.66666666666666%
# chatgpt arithmetic mean acc: 50.0%
# code arithmetic mean false positive: 8.333333333333332%
# chatgpt arithmetic mean false positive: 8.333333333333332%
# -----
# 1744638094383360
# validation acronyms ['UNV', 'CO', 'GCCF', 'CFN', 'UNDP', 'GEF', 'GCCF-III', 'TOR', 'MOF', 'MoFE', 'CCMD', 'PA', 'RBAP', 'BRH', 'ICIMOD', 'FCDO', 'CARA', 'LoCAL', 'NDC', 'NAP', 'MRV', 'MS', 'UNCDF']
# processed acronyms ['UNV', 'CO', 'CFN', 'UNDP', 'GCF', 'GEF', 'UN', 'MOF', 'MoFE', 'PA', 'RBAP', 'BRH', 'UNCDF', 'UN-Women', 'FCDO', 'CARA', 'LoCAL', 'EU', 'NAP', 'MRV', 'MS']
# code arithmetic mean acc: 73.91304347826086%
# chatgpt arithmetic mean acc: 60.86956521739131%
# code arithmetic mean false positive: 17.391304347826086%
# chatgpt arithmetic mean false positive: 21.73913043478261%
# -----
# 1728361581305088
# validation acronyms ['UNDP', 'PVTG', 'PMU', 'CCD', 'ST', 'VLA', 'INR', 'UNV']
# processed acronyms ['UNDP', 'PVTG', 'PMU', 'CCD', 'UN', 'INR', 'UNV']
# code arithmetic mean acc: 75.0%
# chatgpt arithmetic mean acc: 50.0%
# code arithmetic mean false positive: 12.5%
# chatgpt arithmetic mean false positive: 25.0%
# -----
# 1723483137819904
# validation acronyms ['UNDP', 'SIDS', 'MCO', 'SAMOA', 'UNSDG', 'FSM', 'RMI']
# processed acronyms ['UN', 'UNDP', 'SDG', 'AIDS', 'MCO', 'UNSDG', 'FSM', 'RMI']
# code arithmetic mean acc: 71.42857142857143%
# chatgpt arithmetic mean acc: 57.14285714285714%
# code arithmetic mean false positive: 42.857142857142854%
# chatgpt arithmetic mean false positive: 42.857142857142854%
# -----
# 1730826777486592
# validation acronyms ['R/R', 'GP', 'DRR', 'GIS', 'UNDP', 'NDMA', 'PDNA', 'VLA', 'INR', 'UNV']
# processed acronyms ['UN', 'GP', 'DRR', 'GIS', 'UNDP', 'NDMA', 'INR', 'UNV']
# code arithmetic mean acc: 70.0%
# chatgpt arithmetic mean acc: 60.0%
# code arithmetic mean false positive: 10.0%
# chatgpt arithmetic mean false positive: 20.0%
# -----
# 1718087658102016
# validation acronyms ['WHO', 'C4H', 'UNV', 'MOH', 'WTO', 'ASEAN', 'MS']
# processed acronyms ['WHO', 'UNV', 'MOH', 'WTO', 'UN', 'ASEAN', 'MS']
# code arithmetic mean acc: 85.71428571428571%
# chatgpt arithmetic mean acc: 57.14285714285714%
# code arithmetic mean false positive: 14.285714285714285%
# chatgpt arithmetic mean false positive: 0.0%
# -----
# 1719869099853056
# validation acronyms ['LMC', 'UNV', 'UNDP', 'NAST', 'FGC', 'MOU', 'TOR', 'CMS']
# processed acronyms ['UN', 'UNV', 'NAST', 'UNDP', 'FGC', 'MOU', 'TOR', 'CMS']
# code arithmetic mean acc: 87.5%
# chatgpt arithmetic mean acc: 87.5%
# code arithmetic mean false positive: 12.5%
# chatgpt arithmetic mean false positive: 12.5%
# -----
# 1730380119308544
# validation acronyms ['CSO', 'UNDP', 'UNV', 'MS']
# processed acronyms ['SDG', 'UN', 'UNDP', 'UNV', 'USD', 'MS']
# code arithmetic mean acc: 75.0%
# chatgpt arithmetic mean acc: 50.0%
# code arithmetic mean false positive: 75.0%
# chatgpt arithmetic mean false positive: 150.0%
# -----
# 1718548951612672
# validation acronyms ['UNAMA', 'DPKO', 'ICSC', 'WBD', 'MS']
# processed acronyms ['UNAMA', 'UN', 'DPKO', 'ICSC']
# code arithmetic mean acc: 60.0%
# chatgpt arithmetic mean acc: 60.0%
# code arithmetic mean false positive: 20.0%
# chatgpt arithmetic mean false positive: 0.0%
# -----
# 1749620970666240
# validation acronyms ['MNCH', 'UNICEF', 'WHO', 'IMNCI', 'ECEB', 'ECSB', 'HBB', 'CCM', 'CBNBC', 'IPC', 'MHPSS', 'PHC', 'BI', 'ODK', 'CDM']
# processed acronyms ['MNCH', 'UN', 'UNV', 'UNICEF', 'WHO', 'IMNCI', 'ECSB', 'CCM', 'IPC', 'PHC', 'ODK']
# code arithmetic mean acc: 60.0%
# chatgpt arithmetic mean acc: 73.33333333333333%
# code arithmetic mean false positive: 13.333333333333334%
# chatgpt arithmetic mean false positive: 6.666666666666667%
# -----
# 1748972773842176
# validation acronyms ['UNDP', 'GoSL', 'UNICEF']
# processed acronyms ['UN', 'UNDP', 'COVID-19', 'GoSL', 'SDG16']
# code arithmetic mean acc: 66.66666666666666%
# chatgpt arithmetic mean acc: 100.0%
# code arithmetic mean false positive: 100.0%
# chatgpt arithmetic mean false positive: 200.0%
# -----
# 1737023049212160
# validation acronyms ['TEPP', 'IP', 'UNDP', 'MDG', 'NHRC', 'PMO', 'BBS', 'IMED', 'BIDA', 'DBID', 'G2B', 'MP', 'GIU', 'LDC', 'NGOAB']
# processed acronyms ['IP', 'UNDP', 'NHRC', 'NGO', 'IMED', 'ICT', 'BIDA', 'GIU', 'NGOAB', 'UN']
# code arithmetic mean acc: 46.666666666666664%
# chatgpt arithmetic mean acc: 46.666666666666664%
# code arithmetic mean false positive: 20.0%
# chatgpt arithmetic mean false positive: 26.666666666666668%
# -----
# 1722555707414784
# validation acronyms ['YuWaah', 'NUNV', 'UPSHIFT', 'CSO', 'SOP', 'UNICEF', 'GenU', 'MNC', 'VLA', 'INR', 'UNV']
# processed acronyms ['NUNV', 'UPSHIFT', 'UN', 'II', 'UNICEF', 'GenU', 'INR', 'USD', 'UNV']
# code arithmetic mean acc: 54.54545454545454%
# chatgpt arithmetic mean acc: 27.27272727272727%
# code arithmetic mean false positive: 27.27272727272727%
# chatgpt arithmetic mean false positive: 54.54545454545454%
# -----
# 1712606683150592
# validation acronyms ['UNV', 'PCA', 'RWP', 'HPM', 'UNICEF', 'CR', 'PM', 'HACT', 'MS']
# processed acronyms ['UNV', 'HPM', 'UNICEF', 'CR', 'PM', 'UN', 'MS', 'ARC']
# code arithmetic mean acc: 66.66666666666666%
# chatgpt arithmetic mean acc: 44.44444444444444%
# code arithmetic mean false positive: 22.22222222222222%
# chatgpt arithmetic mean false positive: 55.55555555555556%
# -----
# 1737192573379840
# validation acronyms ['LoCAL', 'UNCDF', 'UNV', 'AGD', 'LGA', 'LDC', 'CCA', 'PBCRG', 'PBCRGS', 'IUNV', 'UNDSS', 'UNDP']
# processed acronyms ['LoCAL', 'UNCDF', 'UN', 'UNV', 'CCA', 'PBCRG', 'IUNV', 'UNDP']
# code arithmetic mean acc: 58.333333333333336%
# chatgpt arithmetic mean acc: 50.0%
# code arithmetic mean false positive: 8.333333333333332%
# chatgpt arithmetic mean false positive: 16.666666666666664%
# -----
# 1717220336857344
# validation acronyms ['UNV', 'CO', 'UNICEF', 'MS']
# processed acronyms ['UNV', 'CO', 'UNICEF', 'UN', 'MS']
# code arithmetic mean acc: 100.0%
# chatgpt arithmetic mean acc: 50.0%
# code arithmetic mean false positive: 25.0%
# chatgpt arithmetic mean false positive: 75.0%
# -----
# 1738258918508800
# validation acronyms ['IUDP', 'GESI', 'DDR', 'UNOPS', 'UNV']
# processed acronyms ['UN', 'IUDP', 'GESI', 'UNOPS', 'UNV', 'GIS']
# code arithmetic mean acc: 80.0%
# chatgpt arithmetic mean acc: 60.0%
# code arithmetic mean false positive: 40.0%
# chatgpt arithmetic mean false positive: 140.0%
# -----
# 1748685903188224
# validation acronyms ['UNV', 'WEF', 'BAPPENAS', 'UNDP', 'FAO']
# processed acronyms ['UNV', 'BAPPENAS', 'UN', 'SDG', 'UNDP', 'FAO']
# code arithmetic mean acc: 80.0%
# chatgpt arithmetic mean acc: 80.0%
# code arithmetic mean false positive: 40.0%
# chatgpt arithmetic mean false positive: 80.0%
# -----
# 1735863691344128
# validation acronyms ['UNDP', 'PMO', 'NIM', 'CICETE', 'VLA', 'RMB']
# processed acronyms ['UNDP', 'SDG', 'PMO', 'UNV', 'NIM', 'CICETE', 'UN', 'UNIDO', 'RMB']
# code arithmetic mean acc: 83.33333333333334%
# chatgpt arithmetic mean acc: 83.33333333333334%
# code arithmetic mean false positive: 66.66666666666666%
# chatgpt arithmetic mean false positive: 16.666666666666664%
# -----
# 1729850533315840
# validation acronyms ['WEE', 'PPT', 'UNGTG', 'ACWF', 'UNV', 'RO', 'RCO', 'UBDP', 'AGD', 'SN', 'VLA', 'CV', 'RMB']
# processed acronyms ['UN', 'WEE', 'PPT', 'EU', 'UNGTG', 'ACWF', 'RO', 'RCO', 'UNDP', 'UNV', 'SN', 'CV']
# code arithmetic mean acc: 69.23076923076923%
# chatgpt arithmetic mean acc: 61.53846153846154%
# code arithmetic mean false positive: 23.076923076923077%
# chatgpt arithmetic mean false positive: 23.076923076923077%
# -----
# 1724294909239552
# validation acronyms ['WEE', 'RAM', 'WFP', 'CO', 'M&E', 'AO', 'UNV', 'AGD', 'MORSS', 'UNDSS', 'MS']
# processed acronyms ['RAM', 'UN', 'WFP', 'CO', 'AO', 'UNV', 'SDG', 'IV', 'MS', 'SPSS']
# code arithmetic mean acc: 54.54545454545454%
# chatgpt arithmetic mean acc: 81.81818181818183%
# code arithmetic mean false positive: 36.36363636363637%
# chatgpt arithmetic mean false positive: 45.45454545454545%
# -----
# 1727287204035840
# validation acronyms ['UNV', 'UNICEF', 'LVPO', 'AGD', 'VLA', 'RMB', 'MS', 'PSEA']
# processed acronyms ['UNV', 'UNICEF', 'CHN-Supply', 'UN', 'RMB', 'MS', 'PSEA']
# code arithmetic mean acc: 62.5%
# chatgpt arithmetic mean acc: 62.5%
# code arithmetic mean false positive: 25.0%
# chatgpt arithmetic mean false positive: 12.5%
# -----
# 1719066042423552
# validation acronyms ['SESEHA', 'PV', 'UNV', 'UNDP', 'ABADEI', 'KfW', 'MS', 'CSO', 'PVSol']
# processed acronyms ['SESEHA', 'UN', 'PV', 'UNV', 'UNDP', 'ABADEI', 'KfW', 'PVSol', 'MS', 'KFW']
# code arithmetic mean acc: 100.0%
# chatgpt arithmetic mean acc: 77.77777777777779%
# code arithmetic mean false positive: 11.11111111111111%
# chatgpt arithmetic mean false positive: 66.66666666666666%
# -----
# 1734838521537792
# validation acronyms ['UNODC', 'UNEP', 'UNV', 'AGD', 'IP', 'UNEP/ROAP', 'MEA', 'MS']
# processed acronyms ['UN', 'UNODC', 'UNEP', 'UNV', 'IP', 'MEA', 'MS']
# code arithmetic mean acc: 75.0%
# chatgpt arithmetic mean acc: 50.0%
# code arithmetic mean false positive: 12.5%
# chatgpt arithmetic mean false positive: 12.5%
# -----
# 1740390291898624
# validation acronyms ['UNV', 'UNICEF', 'AGD', 'UNSMS', 'DSA', 'MS']
# processed acronyms ['UNV', 'UNICEF', 'UN', 'UNSMS', 'MS']
# code arithmetic mean acc: 66.66666666666666%
# chatgpt arithmetic mean acc: 66.66666666666666%
# code arithmetic mean false positive: 16.666666666666664%
# chatgpt arithmetic mean false positive: 16.666666666666664%
# -----
# 1735158341286144
# validation acronyms ['UNV', 'UNDP', 'MCO', 'ID', 'DSA', 'SOP', 'MCPD', 'UNSDCF', 'PIC', 'MS']
# processed acronyms ['UNV', 'UN', 'UNDP', 'MCO', 'MCPD', 'UNSDCF', 'MS']
# code arithmetic mean acc: 60.0%
# chatgpt arithmetic mean acc: 60.0%
# code arithmetic mean false positive: 10.0%
# chatgpt arithmetic mean false positive: 30.0%
# -----
# 1720381855226112
# validation acronyms ['UNDP', 'Gov4Res', 'GESI', 'CSO', 'MEAL', 'M&E', 'PIANGO', 'AGD', 'PIC', 'PFM', 'MS']
# processed acronyms ['UNDP', 'UN', 'GESI', 'CSO', 'UNV', 'QA', 'SDG', 'PIC', 'PFM', 'MS']
# code arithmetic mean acc: 54.54545454545454%
# chatgpt arithmetic mean acc: 54.54545454545454%
# code arithmetic mean false positive: 36.36363636363637%
# chatgpt arithmetic mean false positive: 27.27272727272727%
# -----
# 1714648120889600
# validation acronyms ['AHF', 'OCHA', 'DD/ICA', 'TPM', 'RCM', 'CBPF', 'HC', 'HFU', 'HRP', 'US', 'GMS', 'UNV']
# processed acronyms ['AHF', 'OCHA', 'TPM', 'RCM', 'CBPF', 'HC', 'NGO', 'UN', 'HRP', 'US', 'UNV', 'GMS', 'COVID-19']
# code arithmetic mean acc: 83.33333333333334%
# chatgpt arithmetic mean acc: 66.66666666666666%
# code arithmetic mean false positive: 25.0%
# chatgpt arithmetic mean false positive: 0.0%
# -----
# 1722330536946944
# validation acronyms ['UNV', 'SCALA', 'MoALD', 'UNDP', 'CO', 'FAO', 'CP', 'TWC', 'PSC', 'NDC', 'NAP', 'AGD', 'NDC', 'BMUB', 'GHG', 'IKI', 'MS']
# processed acronyms ['UNV', 'SCALA', 'UNDP', 'HQ', 'CO', 'CP', 'FAO', 'UN', 'TWC', 'PSC', 'NDC', 'II', 'IKI', 'GHG', 'MS']
# code arithmetic mean acc: 70.58823529411765%
# chatgpt arithmetic mean acc: 64.70588235294117%
# code arithmetic mean false positive: 17.647058823529413%
# chatgpt arithmetic mean false positive: 23.52941176470588%
# -----
# 1728272560700672
# validation acronyms ['UNDP', 'PMU', 'UNDP', 'SDG', 'ST', 'VLA', 'INR', 'UNV', 'ASP']
# processed acronyms ['UNDP', 'PMU', 'UN', 'INR', 'UNV', 'ICT', 'ASP', 'AJAX']
# code arithmetic mean acc: 55.55555555555556%
# chatgpt arithmetic mean acc: 33.33333333333333%
# code arithmetic mean false positive: 33.33333333333333%
# chatgpt arithmetic mean false positive: 77.77777777777779%
# -----
# 1749249816247552
# validation acronyms ['UNA', 'RCR', 'SOP', 'DPKO', 'UNAMA', 'MS']
# processed acronyms ['UN', 'UNA', 'RCR', 'UNAMA', 'DPKO', 'MS']
# code arithmetic mean acc: 83.33333333333334%
# chatgpt arithmetic mean acc: 50.0%
# code arithmetic mean false positive: 16.666666666666664%
# chatgpt arithmetic mean false positive: 33.33333333333333%
# -----
# 1722882212262144
# validation acronyms ['IPRCC', 'IVD', 'UNV', 'UNDP', 'VLA', 'RMB', 'NUNV']
# processed acronyms ['UN', 'IPRCC', 'UNV', 'IVD', 'UNDP', 'COVID-19', 'SDG', 'SDG1', 'SDG5', 'RMB', 'NUNV']
# code arithmetic mean acc: 85.71428571428571%
# chatgpt arithmetic mean acc: 71.42857142857143%
# code arithmetic mean false positive: 71.42857142857143%
# chatgpt arithmetic mean false positive: 14.285714285714285%
# -----
# 1724193944727808
# validation acronyms ['UNV', 'SBC', 'UNICEF', 'C4D', 'MS', 'RCCE']
# processed acronyms ['UNV', 'SBC', 'UN', 'UNICEF', 'RCCE', 'MS']
# code arithmetic mean acc: 83.33333333333334%
# chatgpt arithmetic mean acc: 66.66666666666666%
# code arithmetic mean false positive: 16.666666666666664%
# chatgpt arithmetic mean false positive: 33.33333333333333%
# -----
# 1719185397717248
# validation acronyms ['ACHIEVE', 'UNV', 'UNDP', 'GoI', 'CO', 'MRT']
# processed acronyms ['ACHIEVE', 'UNV', 'UNDP', 'UN', 'GoI', 'SDG', 'CO', 'MRT']
# code arithmetic mean acc: 100.0%
# chatgpt arithmetic mean acc: 83.33333333333334%
# code arithmetic mean false positive: 33.33333333333333%
# chatgpt arithmetic mean false positive: 16.666666666666664%
# -----
# 1737637619526912
# validation acronyms ['BSST', 'PSST', 'UNV', 'CSO', 'UNICEF']
# processed acronyms ['UN', 'BSST', 'UNV', 'CSO', 'UNICEF']
# code arithmetic mean acc: 80.0%
# chatgpt arithmetic mean acc: 80.0%
# code arithmetic mean false positive: 20.0%
# chatgpt arithmetic mean false positive: 0.0%
# -----
# 1720842403517696
# validation acronyms ['NIS', 'SMART', 'MUAC', 'T4D', 'IN-FORM', 'ODK', 'OCHA', 'IM', 'WG', 'HRP', 'HNO', 'HPC', 'PIN', 'UNICEF', 'IDP']
# processed acronyms ['UN', 'NIS', 'MUAC', 'ODK', 'OCHA', 'IM', 'HNO', 'PIN', 'UNICEF', 'COVID-19', 'ArcGIS', 'QGIS', 'BI']
# code arithmetic mean acc: 53.333333333333336%
# chatgpt arithmetic mean acc: 73.33333333333333%
# code arithmetic mean false positive: 33.33333333333333%
# chatgpt arithmetic mean false positive: 20.0%
# -----
# 1707487970160896
# validation acronyms ['CRVS', 'UNV', 'ESCAP', 'AGD', 'SDG', 'BTS', 'MRT', 'MS']
# processed acronyms ['UN', 'CRVS', 'UNV', 'ESCAP', 'US', 'BTS', 'MRT', 'MS']
# code arithmetic mean acc: 75.0%
# chatgpt arithmetic mean acc: 100.0%
# code arithmetic mean false positive: 25.0%
# chatgpt arithmetic mean false positive: 25.0%
# -----
# 1736341011691776
# validation acronyms ['UNAMA', 'DPKO', 'UNV', 'UNOCA', 'SRSG', 'BOQ']
# processed acronyms ['UN', 'UNAMA', 'DPKO', 'UNOCA', 'USD', 'BOQ']
# code arithmetic mean acc: 66.66666666666666%
# chatgpt arithmetic mean acc: 66.66666666666666%
# code arithmetic mean false positive: 33.33333333333333%
# chatgpt arithmetic mean false positive: 116.66666666666667%
# -----
# 1741892835062016
# validation acronyms ['EFMS', 'FMU', 'SAO', 'VIP', 'UNAMA', 'FSS', 'UNAMA-HQ', 'UNOCA', 'AFP', 'RAO', 'FTS', 'DPKO']
# processed acronyms ['UN', 'EFMS', 'SAO', 'UNAMA', 'FSS', 'AFP', 'UNAMA-HQ', 'UNOCA', 'HR', 'HQ', 'FTS', 'DPKO', 'USD']
# code arithmetic mean acc: 75.0%
# chatgpt arithmetic mean acc: 0.0%
# code arithmetic mean false positive: 33.33333333333333%
# chatgpt arithmetic mean false positive: 8.333333333333332%
# -----
# 1725981123357952
# validation acronyms ['UNV', 'UNICEF', 'WASH', 'MRT', 'MS']
# processed acronyms ['UN', 'UNICEF', 'UNV', 'MRT', 'MS']
# code arithmetic mean acc: 80.0%
# chatgpt arithmetic mean acc: 100.0%
# code arithmetic mean false positive: 20.0%
# chatgpt arithmetic mean false positive: 80.0%
# -----
# 1710941565686016
# validation acronyms ['UNAMA', 'ISW', 'SOW', 'UMOJA', 'MOO', 'SES', 'UNV', 'DPKO', 'UNOCA', 'SRSG']
# processed acronyms ['UN', 'UNAMA', 'ISW', 'UMOJA', 'SES', 'UNV', 'DPKO', 'UNOCA', 'USD']
# code arithmetic mean acc: 70.0%
# chatgpt arithmetic mean acc: 60.0%
# code arithmetic mean false positive: 20.0%
# chatgpt arithmetic mean false positive: 40.0%
# -----
# 1711631973231872
# validation acronyms ['HCWM', 'CO', 'UNDP', 'MDG', 'LDC', 'UMIC', '8FYP', 'EPU']
# processed acronyms ['HCWM', 'SDG', 'UNDP', 'CO', '8FYP', 'EPU', 'UN']
# code arithmetic mean acc: 62.5%
# chatgpt arithmetic mean acc: 75.0%
# code arithmetic mean false positive: 25.0%
# chatgpt arithmetic mean false positive: 50.0%
# -----
# 1746577951591680
# validation acronyms ['UNV', 'UVP', 'VSC', 'VSS', 'UNDP', 'PNG', 'STD', 'AC']
# processed acronyms ['UNV', 'UN', 'UVP', 'VSC', 'VSS', 'FU', 'ICT', 'UNDP', 'PNG', 'AC']
# code arithmetic mean acc: 87.5%
# chatgpt arithmetic mean acc: 62.5%
# code arithmetic mean false positive: 37.5%
# chatgpt arithmetic mean false positive: 100.0%
# -----
# 1727654131130624
# validation acronyms ['SEADPRI', 'SEADPRI-UKM', 'DRR', 'UNV', 'UNDP', 'UNSDCF', 'YELL', 'UNICEF', 'ALAM', 'LESTARI']
# processed acronyms ['UN', 'SEADPRI', 'SEADPRI-UKM', 'YELL', 'DRR', 'UNDP', 'UNSDCF', 'ALAM', 'LESTARI']
# code arithmetic mean acc: 80.0%
# chatgpt arithmetic mean acc: 70.0%
# code arithmetic mean false positive: 10.0%
# chatgpt arithmetic mean false positive: 20.0%
# -----
# 1717131082592512
# validation acronyms ['VAT', 'UNDP', 'SOP', 'UNDP', 'ANPDF', 'CO', 'MS']
# processed acronyms ['UN', 'VAT', 'UNDP', 'UNV', 'Framework-ANPDF', 'CO', 'MS']
# code arithmetic mean acc: 57.14285714285714%
# chatgpt arithmetic mean acc: 42.857142857142854%
# code arithmetic mean false positive: 42.857142857142854%
# chatgpt arithmetic mean false positive: 71.42857142857143%
# -----
# 1732533350239488
# validation acronyms ['UNICEF', 'NGO', 'BCO', 'RC', 'PPD', 'RMPU', 'CPD', 'PMR', 'P3', 'MS']
# processed acronyms ['UNICEF', 'UN', 'NGO', 'BCO', 'COVID-19', 'CPD', 'PMR', 'UNV', 'MS']
# code arithmetic mean acc: 60.0%
# chatgpt arithmetic mean acc: 80.0%
# code arithmetic mean false positive: 30.0%
# chatgpt arithmetic mean false positive: 20.0%
# -----
# 1729507457681664
# validation acronyms ['PMO', 'IVD', 'UNDP', 'UNV', 'UNFPA', 'UNOPS', 'BYL', 'CICETE', 'BVF', 'VLA', 'RMB']
# processed acronyms ['PMO', 'UN', 'UNV', 'IVD', 'UNDP', 'BYL', 'BVF', 'VLA', 'RMB']
# code arithmetic mean acc: 72.72727272727273%
# chatgpt arithmetic mean acc: 63.63636363636363%
# code arithmetic mean false positive: 9.090909090909092%
# chatgpt arithmetic mean false positive: 9.090909090909092%
# -----
# 1728461550524672
# validation acronyms ['UNICEF', 'ECM', 'CP', 'UNV', 'AGD', 'POCSO', 'CSO', 'VLA', 'INR', 'WHO', 'ICO']
# processed acronyms ['UNICEF', 'UN', 'ECM', 'UNV', 'ICO', 'INR', 'USD']
# code arithmetic mean acc: 45.45454545454545%
# chatgpt arithmetic mean acc: 0.0%
# code arithmetic mean false positive: 18.181818181818183%
# chatgpt arithmetic mean false positive: 9.090909090909092%
# -----
# 1726533237289216
# validation acronyms ['SA', 'NOO', 'HCFC', 'HPMP', 'KIP', 'MLF', 'PCR', 'NOU', 'PCA', 'SSFA', 'UN2UN', 'UNEP', 'CAP', 'UNV', 'AGD', 'ODS', 'HCFC', 'RAC', 'GWP', 'UNDP', 'UNIDO', 'GIZ', 'BTS', 'MRT', 'MS']
# processed acronyms ['UN', 'SA', 'NOO', 'HCFC', 'HPMP', 'HFC', 'KIP', 'MLF', 'UNEP', 'CAP', 'UNV', 'ODS', 'RAC', 'UNDP', 'UNIDO', 'GIZ', 'US', 'BTS', 'MRT', 'MS']
# code arithmetic mean acc: 68.0%
# chatgpt arithmetic mean acc: 60.0%
# code arithmetic mean false positive: 12.0%
# chatgpt arithmetic mean false positive: 4.0%
# -----
# 1745158053526784
# validation acronyms ['PMR', 'UNICEF', 'OM', 'ISCG', 'IMWG', 'INTPA', 'FMM', 'AGD']
# processed acronyms ['PMR', 'UNICEF', 'UN', 'GIS', 'GPS', 'INTPA']
# code arithmetic mean acc: 37.5%
# chatgpt arithmetic mean acc: 87.5%
# code arithmetic mean false positive: 37.5%
# chatgpt arithmetic mean false positive: 25.0%
# -----
# 1738203900331264
# validation acronyms ['UNDP', 'CO', 'CSO', 'AGD', 'CSDG', 'STA', 'MORSS']
# processed acronyms ['UN', 'UNDP', 'CO', 'CSO', 'STA']
# code arithmetic mean acc: 57.14285714285714%
# chatgpt arithmetic mean acc: 85.71428571428571%
# code arithmetic mean false positive: 14.285714285714285%
# chatgpt arithmetic mean false positive: 57.14285714285714%
# -----
# 1717366139706624
# validation acronyms ['FAO', 'MEAL', 'IPC', 'CPF', 'UNV', 'MORSS', 'M&E']
# processed acronyms ['FAO', 'UN', 'UNV', 'UNSDCF', 'IPC', 'COVID-19']
# code arithmetic mean acc: 42.857142857142854%
# chatgpt arithmetic mean acc: 100.0%
# code arithmetic mean false positive: 42.857142857142854%
# chatgpt arithmetic mean false positive: 14.285714285714285%
# -----
# 268
# weighted arithmetic code accuracy 66.87022900763357%
# weighted arithmetic chatgpt accuracy 58.77862595419848%
# weighted arithmetic code false postives 23.51145038167937%
# weighted arithmetic chatgpt false positives 28.244274809160288%
# wighted arithmetic acronym expanded form detection accuracy 69.40298507462687%
